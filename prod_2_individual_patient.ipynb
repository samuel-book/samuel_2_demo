# %% [markdown]
# # Individual patient model

# %%
import warnings
warnings.filterwarnings("ignore")

from utils.individual_patient import IndividualPatientModel

# %% [markdown]
# ## Choose to use artificial or real data
#
# This repository only contains artificial data

# %%
use_artificial_data = False

if use_artificial_data:
    data_path = './artificial_data'
else:
    data_path = './real_data'

# %%
# Retrain models if required (otherwise load saved models)
train_models = True
replicates = 30

pm = IndividualPatientModel(
    data_path, train_models=train_models, replicates=replicates)
# Out:
# Training thrombolysis choice models...
# Training thrombolysis outcome models...

# %% [markdown]
# Define an example patient.

# %%
patient = {
    'infarction': 1,
    'prior_disability': 0,
    'stroke_severity': 4,
    'stroke_team': "Royal Lancaster Infirmary",
    'onset_to_arrival_time': 80,
    'arrival_to_scan_time': 20,
    'precise_onset_known': 1,
    'onset_during_sleep': 0,
    'onset_to_thrombolysis': 150,
    'age': 65,
    'any_afib_diagnosis': 0,
    'afib_anticoagulant': 0}

filename = 'example_patient_mild_stroke_late'
pm.predict_patient(
    patient, save=True, filename=filename, anon=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 16
#       1 patient = {
#       2     'infarction': 1,
#       3     'prior_disability': 0,
#    (...)
#      12     'any_afib_diagnosis': 0,
#      13     'afib_anticoagulant': 0}
#      15 filename = 'example_patient_mild_stroke_late'
# ---> 16 pm.predict_patient(
#      17     patient, save=True, filename=filename, anon=True)
#
# File ~/Insync/michael.allen1966@gmail.com/OneDrive/01_Git_Current/1b_SAMueL_key_repos/samuel_2_demo/utils/individual_patient.py:243, in IndividualPatientModel.predict_patient(self, patient_data, save, filename, anon)
#     241 patient_choice = patient[fields]
#     242 enc = OneHotEncoder(categories=[self.stroke_teams])
# --> 243 one_hot = enc.fit_transform(patient_choice[['stroke_team']]).toarray()
#     244 one_hot = pd.DataFrame(one_hot, columns=self.stroke_teams)
#     245 patient_choice = pd.concat([patient_choice, one_hot], axis=1)
#
# File ~/miniconda3/envs/samprod/lib/python3.10/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~/miniconda3/envs/samprod/lib/python3.10/site-packages/sklearn/base.py:915, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     911 # non-optimized default implementation; override when a better
#     912 # method is possible for a given clustering algorithm
#     913 if y is None:
#     914     # fit method of arity 1 (unsupervised transformation)
# --> 915     return self.fit(X, **fit_params).transform(X)
#     916 else:
#     917     # fit method of arity 2 (supervised transformation)
#     918     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/miniconda3/envs/samprod/lib/python3.10/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/envs/samprod/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:982, in OneHotEncoder.fit(self, X, y)
#     972     warnings.warn(
#     973         (
#     974             "`sparse` was renamed to `sparse_output` in version 1.2 and "
#    (...)
#     978         FutureWarning,
#     979     )
#     980     self.sparse_output = self.sparse
# --> 982 self._fit(
#     983     X,
#     984     handle_unknown=self.handle_unknown,
#     985     force_all_finite="allow-nan",
#     986 )
#     987 self._set_drop_idx()
#     988 self._n_features_outs = self._compute_n_features_outs()
#
# File ~/miniconda3/envs/samprod/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:144, in _BaseEncoder._fit(self, X, handle_unknown, force_all_finite, return_counts, return_and_ignore_missing_for_infrequent)
#     139     if diff:
#     140         msg = (
#     141             "Found unknown categories {0} in column {1}"
#     142             " during fit".format(diff, i)
#     143         )
# --> 144         raise ValueError(msg)
#     145 if compute_counts:
#     146     category_counts.append(_get_counts(Xi, cats))
#
# ValueError: Found unknown categories ['Royal Lancaster Infirmary'] in column 0 during fit
